# %%
c = 0
while c <= 5:
    c+=1
    print("c vale",c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# c vale 4
# c vale 5
# c vale 6

# %%
c=0
while c <=5: 
    c+=1
    print("c vale", c)
else:
    print ("se ha completado toda la iteracion y c vale", c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# c vale 4
# c vale 5
# c vale 6
# se ha completado toda la iteracion y c vale 6

# %%
c=0
while c <=5: 
    c+=1
    if ( c == 4):
        print("rompemos el bucle cuando c vale", c)
        break
    print("c vale", c)
else:
    print ("se ha completado toda la iteracion y c vale", c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# rompemos el bucle cuando c vale 4

# %%
c=0
while c <=5: 
    c+=1
    if ( c == 4):
        print("continuamos con la siguiente iteracion",)
        continue
    print("c vale", c)
else:
    print ("se ha completado toda la iteracion y c vale", c)
# Out:
# c vale 1
# c vale 2
# c vale 3
# continuamos con la siguiente iteracion 4
# c vale 5
# c vale 6
# se ha completado toda la iteracion y c vale 6

# %%
print("Bienvenido al menu interativo")
while (True):
    print("""Que quieres hacer, escribe una opcion
    1) Saludar
    2) sumar 2 numeros
    3) salir """)
    opcion= input()
    if opcion == '1':
        print("Hola")
    elif opcion =='2':
          n1= float(input("introduce el primer numero"))
          n2 = float(input("introduce el segundo numero"))
          print( n1+n2)
    elif opcion =='3':
        print("saliendo...")
        break
    else:
       print("no es una opcion valida")
# Out:
# Bienvenido al menu interativo
# Que quieres hacer, escribe una opcion
#     1) Saludar
#     2) sumar 2 numeros
#     3) salir
#  1
# Hola
# Que quieres hacer, escribe una opcion
#     1) Saludar
#     2) sumar 2 numeros
#     3) salir
#  2
# introduce el primer numero 4
# introduce el segundo numero 5
# 9.0
# Que quieres hacer, escribe una opcion
#     1) Saludar
#     2) sumar 2 numeros
#     3) salir
#  3
# saliendo...

# %%
print("introduzca su contraseña")
contraseña= input()
intentos= 3
while intentos > 0 and intentos < 4:
    intentos-=1
    if contraseña == "python123":
       print("acceso concedido")
       break
    elif intentos == 0:
        print("cuenta bloqueada")
    else:
        print("INCORRECTA, te quedan" + str(intentos) + "intentos")
        contraseña= input("introduzca su contraseña")
# Out:
# introduzca su contraseña
#  hola
# INCORRECTA, te quedan2intentos
# introduzca su contraseña python123
# acceso concedido
