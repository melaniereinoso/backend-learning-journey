# %%
#igual que 
3==2
# Out:
# False

# %%
#distinto que
3!=2
# Out:
# True

# %%
#mayor que 
3>2
# Out:
# True

# %%
#menor que
3<2
# Out:
# False

# %%
#mayor o igual que
3<=3
# Out:
# True

# %%
#menor o igual
3<=4
# Out:
# True

# %%
a=10
b=5
a>b
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
a==b*2
# Out:
# True

# %%
'hola' == 'Hola'
# Out:
# False

# %%
'hola' != 'Hola'
# Out:
# True

# %%
c= "Hola"
c[0] == "H"
# Out:
# True

# %%
l1=[0,1,2]
l2=[2,2,4]
l1==l2
# Out:
# False

# %%
len(l1)==len(l2)
# Out:
# True

# %%
l1[-1]==l2[0]
# Out:
# True

# %%
True==True
# Out:
# True

# %%
True!=True
# Out:
# False

# %%
True> False
# Out:
# True

# %%
True< False
# Out:
# False

# %%
#true=1
#false=0
