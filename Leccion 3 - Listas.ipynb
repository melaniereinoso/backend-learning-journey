# %%
numeros=[1,2,3,4]

# %%
datos=[4,"una cadena",-15,3.14,"otra cadena"]

# %%
datos[0]
# Out:
# 4

# %%
datos[-1]
# Out:
# 'otra cadena'

# %%
datos[-2:]
# Out:
# [3.14, 'otra cadena']

# %%
pares=[0,2,4,5,8]

# %%
pares[3]=6

# %%
pares
# Out:
# [0, 2, 4, 6, 8]

# %%
pares.append(12) #para agregar numeros al final

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 12]

# %%
pares.append(7*2)

# %%
pares
# Out:
# [0, 2, 4, 6, 8, 12, 12, 14]

# %%
letras = ['a','b','c','d','e','f']

# %%
letras[:3]
# Out:
# ['a', 'b', 'c']

# %%
letras[:3]= ['A', 'B', 'C']

# %%
letras
# Out:
# ['A', 'B', 'C', 'd', 'e', 'f']

# %%
letras[:3]= []

# %%
letras
# Out:
# ['d', 'e', 'f']

# %%
a=[1,2,3]
b=[4,5,6]
c=[7,8,9]
R= [a,b,c]

# %%
R
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
R[0]
# Out:
# [1, 2, 3]

# %%
R[-1]
# Out:
# [7, 8, 9]

# %%
R[0][0]
# Out:
# 1

# %%
R[1][1]
# Out:
# 5
