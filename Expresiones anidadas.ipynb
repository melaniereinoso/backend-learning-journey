# %%
a=10
b=5
a*b-2**b>=20 and not (a % b )!= 0
# Out:
# False

# %% [markdown]
# orden de precedencia.
# primero los parentesis porque tiene prioridad.
# luego experienciones aritmeticas por sus reglas, primero exponentes y raices, luego multiplicacion y divisiones y finalmente sumas y restas. Siempre de izquierda a derecha.
# tercero, los relacionesles, de izquiera a derecha, y al final los logicos)
