# %% [markdown]
# Es el operador and
#
#  Significa: “y”
#
# Solo es True si ambas condiciones son verdaderas.
#
# Ejemplos:

# %%
not False
# Out:
# True

# %%
not False == True
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
a= 10
a>7 and a<20
# Out:
# True

# %% [markdown]
#  Disyunción (OR)
#
# Es el operador or
#
# Significa: “o”
#
# Es True si al menos una condición es verdadera.
#
# Ejemplos:

# %%
True or False   # True
False or False  # False
True or True    # True
# Out:
# True
